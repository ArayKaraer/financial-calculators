# %% [markdown]
# <a href="https://colab.research.google.com/github/ArayKaraer/financial-calculators/blob/main/crypto-trend-analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def analyze_market_trends(price_list,x):
 average_price = sum(price_list) / len(price_list)
 max_value = max(price_list)
 min_value = min(price_list)
 higher_than_average = [price for price in prices if price > average_price]
 lower_than_average = [price for price in prices if price < average_price]

 if  0 <= x <= 9 and price_list[x] < average_price:
    print("Price is below average")
 elif  0 <= x <= 9 and price_list[x] == average_price :
    print("Price is equal to average")
 else:
    print("Price is upper average")



 print("Average Price:",average_price)
 print("Maximum Price:",max_value)
 print("Minimum Price:",min_value)
 print("Prices higher than average:",higher_than_average)
 print("Prices lower than average:",lower_than_average)


x = int(input("Please write your day number:"))


prices = [42.0, 44.5, 43.1, 46.0, 48.2, 47.0, 49.5, 51.0, 50.2, 53.0]
analyze_market_trends(prices,x-1)
# Out:
# Please write your day number:6
# Price is below average
# Average Price: 47.45
# Maximum Price: 53.0
# Minimum Price: 42.0
# Prices higher than average: [48.2, 49.5, 51.0, 50.2, 53.0]
# Prices lower than average: [42.0, 44.5, 43.1, 46.0, 47.0]
